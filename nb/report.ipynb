# %% [markdown]
# ## Build Container Image - Checklist

# %% [markdown]
# 1. Complete Build Container Image Assignment
# - `Done!`
#
# 2. Submit the link to the folder in your forked repo with the completed assignment that contains your Dockerfile.
# - `https://github.com/chrisogonas/stock-predictor`

# %%
# 3. Screenshot of the docker run command successfully executing.
from IPython.display import Image, display
display(Image(filename = '../img/docker_sshot.jpg'))

# %% [markdown]
# 4. What does it mean to create a Docker image and why do we use Docker images?
# - `It means creating a read-only template that contains a set of instructions for creating a container that can run on the Docker platform.`
#
# - `Docker images make it convenient to package up applications and preconfigured server environments, and share them easily. This also translates into effient use of time since users do not have to recreate an image from scratch.`
#
# 5. Explain the difference between a Container and Virtual Machine
# - `VM is a virtual computer i.e. a software that provides full functionalities of a computer. It has its operating system and allows for installation of software. software directly on the computer. A container is a software code package containing an application's code, its libraries, and other dependencies.`
#
# - `VM virtualizes the computer system.	While containers virtualize the operating system only.`
#
#
# 6. What are 5 examples of container orchestration tools?
#
# - `Kubernetes`
# - `Openshift`
# - `Nomad`
# - `Docker`
# - `Mesos`
#
# 7. How does a Docker image differ from a Docker container?
# - `A Docker image is a read-only immutable template that specifies how a container will be realized. A Docker container is a runtime instance of a Docker image that gets created when the $docker run command is invoked.`
